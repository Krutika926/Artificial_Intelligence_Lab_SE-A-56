# %% [markdown]
# <a href="https://colab.research.google.com/github/Krutika926/Artificial_Intelligence_Lab_SE-A-56/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Example usage:
number = 5
print(f"The factorial of {number} is {factorial(number)}")

number = 0
print(f"The factorial of {number} is {factorial(number)}")

number = -3
print(f"The factorial of {number} is {factorial(number)}")
# Out:
# The factorial of 5 is 120
# The factorial of 0 is 1
# The factorial of -3 is Factorial is not defined for negative numbers

# %%
def display_multiplication_table(num):
    print(f"Multiplication Table for {num}:")
    for i in range(1, 11):  # Table from 1 to 10
        print(f"{num} x {i} = {num * i}")

# Example usage:
number_to_table = 7
display_multiplication_table(number_to_table)

print("\n") # Add a newline for better readability between examples

number_to_table = 12
display_multiplication_table(number_to_table)
# Out:
# Multiplication Table for 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
#
# Multiplication Table for 12:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %%
def check_odd_even(number):
    if number % 2 == 0:
        return f"{number} is an even number."
    else:
        return f"{number} is an odd number."

# Example usage:
num1 = 4
print(check_odd_even(num1))

num2 = 7
print(check_odd_even(num2))

num3 = 0
print(check_odd_even(num3))
# Out:
# 4 is an even number.
# 7 is an odd number.
# 0 is an even number.

# %%
def is_palindrome(number):
    # Convert the number to a string
    num_str = str(number)
    # Check if the string is equal to its reverse
    if num_str == num_str[::-1]:
        return f"{number} is a palindrome."
    else:
        return f"{number} is not a palindrome."

# Example usage:
num1 = 121
print(is_palindrome(num1))

num2 = 123
print(is_palindrome(num2))

num3 = 1221
print(is_palindrome(num3))

num4 = -101 # Negative numbers are typically not considered palindromes in this context
print(is_palindrome(num4))
# Out:
# 121 is a palindrome.
# 123 is not a palindrome.
# 1221 is a palindrome.
# -101 is not a palindrome.
