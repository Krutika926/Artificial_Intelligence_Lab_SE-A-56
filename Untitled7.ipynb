# %% [markdown]
# <a href="https://colab.research.google.com/github/Krutika926/Artificial_Intelligence_Lab_SE-A-56/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STEP 1: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# STEP 2: Load Datasets

# %%
df = pd.read_csv("retail_sales_dataset.csv")

# %% [markdown]
# STEP 3: Data Preprocessing

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M').astype(str)

# %% [markdown]
# STEP 4: Total Sales and Total Units Solid

# %%
total_sales = df['Total Amount'].sum()
total_units = df['Quantity'].sum()

print("Total Sales:", total_sales)
print("Total Units Sold:", total_units)
# Out:
# Total Sales: 456000
# Total Units Sold: 2514

# %% [markdown]
# STEP 5: Top Products by Sales (Bar Chart)

# %%
top_products = df.groupby('Product Category')['Total Amount'].sum().nlargest(5)

plt.figure()
top_products.plot(kind='bar')
plt.title("Top Products by Sales")
plt.xlabel("Product Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# STEP 6: Sales by Region (Using Category as Region)

# %%
sales_region = df.groupby('Product Category')['Total Amount'].sum()

plt.figure()
sales_region.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# STEP 7: Monthly Sales Trend (Line Chart)

# %%
monthly_sales = df.groupby('Month')['Total Amount'].sum()

plt.figure()
monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()
